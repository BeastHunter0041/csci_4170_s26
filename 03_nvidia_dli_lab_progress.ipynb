# %% [markdown]
# <a href="https://colab.research.google.com/github/BeastHunter0041/csci_4170_s26/blob/main/03_nvidia_dli_lab_progress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ia. Rows which returned 'true': 3058, these rows were removed
# ib. Columns created from splitting the categories: 5
#     Facet by each of these individual columns created, and remove the row which have blanks in any of them.
#     Drops down to 1419 Rows after this
#
# ii. Resulting # of clusters from different methods:
# - Fingerprint: 68
# - n-Gram (n = 2): 68
# - n-Gram (n = 3): 69
# - Metaphone3: 149
# - Cologne phonetic: 93
# - Daitch-Motokoff: 160
# - Bieder-Morse: 97
#
# Daitch-Motokoff results in the most clusters.
#
# iii. GREL Expression: if(isBlank(value), "Unbranded", value)
#
# iv. There is no 'price' column in the dataset, so I cannot complete this checkpoint. However, this could have been the possible GREL expression: if(value > 100, 1, 0)
#
# v. GREL expression: if(or(contains(toLowercase(value),"discount"),contains(toLowercase(value),"offer"),contains(toLowercase(value),"sale")),1,0)
